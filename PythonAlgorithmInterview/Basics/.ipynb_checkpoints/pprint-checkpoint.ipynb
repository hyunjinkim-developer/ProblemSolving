# %%
import pprint

nums = [1, 2, 3]

# pprint.pprint() : Show all variables in local scope
pprint.pprint(locals())
# Out:
# {'In': ['',
#         'import pprint\n\npprint(locals())',
#         'import pprint\n\nnums = [2, 3, 4, 5]\n\npprint(locals())',
#         'import pprint\n\nnums = [2, 3, 4, 5]\n\npprint(locals())',
#         'import pprint\n\nnums = [2, 3, 4, 5]\n\npprint(locals())',
#         'import pprint\n\nnums = [2, 3, 4, 5]\n\npprint.pprint(locals())',
#         'new_nums = [4, 5, 6]\n'
#         '\n'
#         '# pprint.pprint() : Show all variables in local scope \n'
#         'pprint.pprint(locals())',
#         'import pprint\n'
#         '\n'
#         'nums = [1, 2, 3]\n'
#         '\n'
#         '# pprint.pprint() : Show all variables in local scope\n'
#         'pprint.pprint(locals())',
#         'import pprint\n'
#         '\n'
#         'nums = [1, 2, 3]\n'
#         '\n'
#         '# pprint.pprint() : Show all variables in local scope\n'
#         'pprint.pprint(locals())',
#         'import pprint\n'
#         '\n'
#         'nums = [1, 2, 3]\n'
#         '\n'
#         '# pprint.pprint() : Show all variables in local scope\n'
#         'pprint.pprint(locals())'],
#  'Out': {},
#  '_': '',
#  '__': '',
#  '___': '',
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__loader__': None,
#  '__name__': '__main__',
#  '__package__': None,
#  '__session__': 'PythonAlgorithmInterview/BasicMethods/pprint.ipynb',
#  '__spec__': None,
#  '_dh': [PosixPath('/Users/hyunjinkim/Documents/ProblemSolving/PythonAlgorithmInterview/BasicMethods')],
#  '_i': 'import pprint\n'
#        '\n'
#        'nums = [1, 2, 3]\n'
#        '\n'
#        '# pprint.pprint() : Show all variables in local scope\n'
#        'pprint.pprint(locals())',
#  '_i1': 'import pprint\n\npprint(locals())',
#  '_i2': 'import pprint\n\nnums = [2, 3, 4, 5]\n\npprint(locals())',
#  '_i3': 'import pprint\n\nnums = [2, 3, 4, 5]\n\npprint(locals())',
#  '_i4': 'import pprint\n\nnums = [2, 3, 4, 5]\n\npprint(locals())',
#  '_i5': 'import pprint\n\nnums = [2, 3, 4, 5]\n\npprint.pprint(locals())',
#  '_i6': 'new_nums = [4, 5, 6]\n'
#         '\n'
#         '# pprint.pprint() : Show all variables in local scope \n'
#         'pprint.pprint(locals())',
#  '_i7': 'import pprint\n'
#         '\n'
#         'nums = [1, 2, 3]\n'
#         '\n'
#         '# pprint.pprint() : Show all variables in local scope\n'
#         'pprint.pprint(locals())',
#  '_i8': 'import pprint\n'
#         '\n'
#         'nums = [1, 2, 3]\n'
#         '\n'
#         '# pprint.pprint() : Show all variables in local scope\n'
#         'pprint.pprint(locals())',
#  '_i9': 'import pprint\n'
#         '\n'
#         'nums = [1, 2, 3]\n'
#         '\n'
#         '# pprint.pprint() : Show all variables in local scope\n'
#         'pprint.pprint(locals())',
#  '_ih': ['',
#          'import pprint\n\npprint(locals())',
#          'import pprint\n\nnums = [2, 3, 4, 5]\n\npprint(locals())',
#          'import pprint\n\nnums = [2, 3, 4, 5]\n\npprint(locals())',
#          'import pprint\n\nnums = [2, 3, 4, 5]\n\npprint(locals())',
#          'import pprint\n\nnums = [2, 3, 4, 5]\n\npprint.pprint(locals())',
#          'new_nums = [4, 5, 6]\n'
#          '\n'
#          '# pprint.pprint() : Show all variables in local scope \n'
#          'pprint.pprint(locals())',
#          'import pprint\n'
#          '\n'
#          'nums = [1, 2, 3]\n'
#          '\n'
#          '# pprint.pprint() : Show all variables in local scope\n'
#          'pprint.pprint(locals())',
#          'import pprint\n'
#          '\n'
#          'nums = [1, 2, 3]\n'
#          '\n'
#          '# pprint.pprint() : Show all variables in local scope\n'
#          'pprint.pprint(locals())',
#          'import pprint\n'
#          '\n'
#          'nums = [1, 2, 3]\n'
#          '\n'
#          '# pprint.pprint() : Show all variables in local scope\n'
#          'pprint.pprint(locals())'],
#  '_ii': 'import pprint\n'
#         '\n'
#         'nums = [1, 2, 3]\n'
#         '\n'
#         '# pprint.pprint() : Show all variables in local scope\n'
#         'pprint.pprint(locals())',
#  '_iii': 'new_nums = [4, 5, 6]\n'
#          '\n'
#          '# pprint.pprint() : Show all variables in local scope \n'
#          'pprint.pprint(locals())',
#  '_oh': {},
#  '_pydevd_bundle': <module '_pydevd_bundle' from '/Applications/PyCharm.app/Contents/plugins/python/helpers/pydev/_pydevd_bundle/__init__.py'>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall object at 0x10f084790>,
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10f077970>>,
#  'new_nums': [4, 5, 6],
#  'nums': [1, 2, 3],
#  'open': <function open at 0x10d967550>,
#  'pprint': <module 'pprint' from '/usr/local/Homebrew/Cellar/python@3.8/3.8.12_1/Frameworks/Python.framework/Versions/3.8/lib/python3.8/pprint.py'>,
#  'pydev_jupyter_vars': <module 'pydev_jupyter_vars' from '/Applications/PyCharm.app/Contents/plugins/python/helpers-pro/jupyter_debug/pydev_jupyter_vars.py'>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall object at 0x10f084790>,
#  'remove_imported_pydev_package': <function remove_imported_pydev_package at 0x10f463430>,
#  'sys': <module 'sys' (built-in)>}

# %%
new_nums = [4, 5, 6]

# pprint.pprint() : Show all variables in local scope
pprint.pprint(locals())
# Out:
# {'In': ['',
#         'import pprint\n\npprint(locals())',
#         'import pprint\n\nnums = [2, 3, 4, 5]\n\npprint(locals())',
#         'import pprint\n\nnums = [2, 3, 4, 5]\n\npprint(locals())',
#         'import pprint\n\nnums = [2, 3, 4, 5]\n\npprint(locals())',
#         'import pprint\n\nnums = [2, 3, 4, 5]\n\npprint.pprint(locals())',
#         'new_nums = [4, 5, 6]\n'
#         '\n'
#         '# pprint.pprint() : Show all variables in local scope \n'
#         'pprint.pprint(locals())',
#         'import pprint\n'
#         '\n'
#         'nums = [1, 2, 3]\n'
#         '\n'
#         '# pprint.pprint() : Show all variables in local scope\n'
#         'pprint.pprint(locals())',
#         'import pprint\n'
#         '\n'
#         'nums = [1, 2, 3]\n'
#         '\n'
#         '# pprint.pprint() : Show all variables in local scope\n'
#         'pprint.pprint(locals())',
#         'import pprint\n'
#         '\n'
#         'nums = [1, 2, 3]\n'
#         '\n'
#         '# pprint.pprint() : Show all variables in local scope\n'
#         'pprint.pprint(locals())',
#         'new_nums = [4, 5, 6]\n'
#         '\n'
#         '# pprint.pprint() : Show all variables in local scope\n'
#         'pprint.pprint(locals())'],
#  'Out': {},
#  '_': '',
#  '__': '',
#  '___': '',
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__loader__': None,
#  '__name__': '__main__',
#  '__package__': None,
#  '__session__': 'PythonAlgorithmInterview/BasicMethods/pprint.ipynb',
#  '__spec__': None,
#  '_dh': [PosixPath('/Users/hyunjinkim/Documents/ProblemSolving/PythonAlgorithmInterview/BasicMethods')],
#  '_i': 'import pprint\n'
#        '\n'
#        'nums = [1, 2, 3]\n'
#        '\n'
#        '# pprint.pprint() : Show all variables in local scope\n'
#        'pprint.pprint(locals())',
#  '_i1': 'import pprint\n\npprint(locals())',
#  '_i10': 'new_nums = [4, 5, 6]\n'
#          '\n'
#          '# pprint.pprint() : Show all variables in local scope\n'
#          'pprint.pprint(locals())',
#  '_i2': 'import pprint\n\nnums = [2, 3, 4, 5]\n\npprint(locals())',
#  '_i3': 'import pprint\n\nnums = [2, 3, 4, 5]\n\npprint(locals())',
#  '_i4': 'import pprint\n\nnums = [2, 3, 4, 5]\n\npprint(locals())',
#  '_i5': 'import pprint\n\nnums = [2, 3, 4, 5]\n\npprint.pprint(locals())',
#  '_i6': 'new_nums = [4, 5, 6]\n'
#         '\n'
#         '# pprint.pprint() : Show all variables in local scope \n'
#         'pprint.pprint(locals())',
#  '_i7': 'import pprint\n'
#         '\n'
#         'nums = [1, 2, 3]\n'
#         '\n'
#         '# pprint.pprint() : Show all variables in local scope\n'
#         'pprint.pprint(locals())',
#  '_i8': 'import pprint\n'
#         '\n'
#         'nums = [1, 2, 3]\n'
#         '\n'
#         '# pprint.pprint() : Show all variables in local scope\n'
#         'pprint.pprint(locals())',
#  '_i9': 'import pprint\n'
#         '\n'
#         'nums = [1, 2, 3]\n'
#         '\n'
#         '# pprint.pprint() : Show all variables in local scope\n'
#         'pprint.pprint(locals())',
#  '_ih': ['',
#          'import pprint\n\npprint(locals())',
#          'import pprint\n\nnums = [2, 3, 4, 5]\n\npprint(locals())',
#          'import pprint\n\nnums = [2, 3, 4, 5]\n\npprint(locals())',
#          'import pprint\n\nnums = [2, 3, 4, 5]\n\npprint(locals())',
#          'import pprint\n\nnums = [2, 3, 4, 5]\n\npprint.pprint(locals())',
#          'new_nums = [4, 5, 6]\n'
#          '\n'
#          '# pprint.pprint() : Show all variables in local scope \n'
#          'pprint.pprint(locals())',
#          'import pprint\n'
#          '\n'
#          'nums = [1, 2, 3]\n'
#          '\n'
#          '# pprint.pprint() : Show all variables in local scope\n'
#          'pprint.pprint(locals())',
#          'import pprint\n'
#          '\n'
#          'nums = [1, 2, 3]\n'
#          '\n'
#          '# pprint.pprint() : Show all variables in local scope\n'
#          'pprint.pprint(locals())',
#          'import pprint\n'
#          '\n'
#          'nums = [1, 2, 3]\n'
#          '\n'
#          '# pprint.pprint() : Show all variables in local scope\n'
#          'pprint.pprint(locals())',
#          'new_nums = [4, 5, 6]\n'
#          '\n'
#          '# pprint.pprint() : Show all variables in local scope\n'
#          'pprint.pprint(locals())'],
#  '_ii': 'import pprint\n'
#         '\n'
#         'nums = [1, 2, 3]\n'
#         '\n'
#         '# pprint.pprint() : Show all variables in local scope\n'
#         'pprint.pprint(locals())',
#  '_iii': 'import pprint\n'
#          '\n'
#          'nums = [1, 2, 3]\n'
#          '\n'
#          '# pprint.pprint() : Show all variables in local scope\n'
#          'pprint.pprint(locals())',
#  '_oh': {},
#  '_pydevd_bundle': <module '_pydevd_bundle' from '/Applications/PyCharm.app/Contents/plugins/python/helpers/pydev/_pydevd_bundle/__init__.py'>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall object at 0x10f084790>,
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10f077970>>,
#  'new_nums': [4, 5, 6],
#  'nums': [1, 2, 3],
#  'open': <function open at 0x10d967550>,
#  'pprint': <module 'pprint' from '/usr/local/Homebrew/Cellar/python@3.8/3.8.12_1/Frameworks/Python.framework/Versions/3.8/lib/python3.8/pprint.py'>,
#  'pydev_jupyter_vars': <module 'pydev_jupyter_vars' from '/Applications/PyCharm.app/Contents/plugins/python/helpers-pro/jupyter_debug/pydev_jupyter_vars.py'>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall object at 0x10f084790>,
#  'remove_imported_pydev_package': <function remove_imported_pydev_package at 0x10f463430>,
#  'sys': <module 'sys' (built-in)>}
