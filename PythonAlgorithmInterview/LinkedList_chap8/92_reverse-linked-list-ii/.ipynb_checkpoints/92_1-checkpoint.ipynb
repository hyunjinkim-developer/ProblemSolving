# %% [markdown]
# # <a href=https://leetcode.com/problems/reverse-linked-list-ii/>reverse-linked-list-ii</a>

# %% [markdown]
# ![image.png](attachment:fa1e365d-197c-482e-a730-7de067ebae2b.png)

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def reverseBetween(self, head: Optional[ListNode], left: int, right: int) -> Optional[ListNode]:
        # Handling exceptions
        if not head or left == right:
            return head

        root = start = ListNode(None)
        root.next = head # to access singly linked list

        # Set start and end
        for _ in range(left - 1):
            start = start.next
        end = start.next

        # Swap nodes
        for _ in range(right - left):
            # Linked in start -> (end.next) -> temp form
            temp, start.next, end.next = start.next, end.next, end.next.next # *
            start.next.next = temp # *

        return root.next
