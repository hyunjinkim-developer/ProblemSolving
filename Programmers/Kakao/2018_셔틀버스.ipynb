# %%
"""
On progress
"""

# from collections import defaultdict
#
# def to_minute(string):
#     h, m = tuple(map(int, string.split(":")))
#     return 60 * h + m
#
# def minute_to_string(minute):
#     h, m = divmod(minute, 60)
#     # string.ljust(length, character)
#     # := left align the string
#     # specified character (space is default) as the fill character.
#     h, m = str(h).rjust(2, "0"), str(m).rjust(2, "0")
#     print(":".join([h, m]))
#     return ":".join([h, m])
#
# def solution(n, t, m, timetable):
#     answer = ''
#     """
#     셔틀 운행 횟수 n,
#     셔틀 운행 간격 t,
#     한 셔틀에 탈 수 있는 최대 크루 수 m
#     """
#
#     # Sort all crew's arrived time
#     timetable = list(to_minute(crew) for crew in timetable)
#     timetable.sort()
#
#     commute = defaultdict(list)
#     # 셔틀은 09:00부터 총 n회 t분 간격으로 역에 도착
#     shuttle_starts = to_minute("09:00")
#     current_shuttle = shuttle_starts
#     total_availables = n * m
# #     shuttle_no = 1
# #     crew_idx = 0
# #     while shuttle_no <= n:
# #         if len(timetable) == crew_idx:
# #             break
#
# #         crew_arrived_at = timetable[crew_idx]
# #         if crew_arrived_at <= current_shuttle:
# #             commute[current_shuttle].append(crew_arrived_at)
# #         crew_idx += 1
#
# #         # current shuttle is full
# #         if len(commute[current_shuttle]) == m:
# #             shuttle_no += 1
# #             if t == 1:
# #                 current_shuttle += t
# #             else:
# #                 cureent_shuttle += (t - 1)
#
# #     print(commute)
#
#     shuttle_no = 0
#     for idx, crew_arrived_at in enumerate(timetable):
#         # if crew arrived later than current shuttle
#         if current_shuttle < crew_arrived_at:
#             # See if the crew can get the next shuttle
#             shuttle_no += 1
#             if n <= shuttle_no:
#                 break
#             if t != 1:
#                 current_shuttle = current_shuttle + t - 1
#             else:
#                 current_shuttle = current_shuttle + t
#
#
#         # if there's more people than capacity of shuttles
#         if total_availables <= idx + 1:
#             # Con should arrived 1 seconds before the last available person
#             answer = crew_arrived_at - 1
#             break
#
#
#         # Current shuttle is full
#         if len(commute[current_shuttle]) == m:
#             shuttle_no += 1
#             if n <= shuttle_no:
#                 break
#             if t != 1:
#                 current_shuttle = current_shuttle + t - 1
#             else:
#                 current_shuttle = current_shuttle + t
#
#         commute[current_shuttle].append(crew_arrived_at)
#
#         print(current_shuttle, idx, crew_arrived_at)
#
#
#     print(commute)
#
#
#
#     # 무사히 셔틀을 타고 사무실로 갈 수 있는 제일 늦은 도착 시각을 출력
#     if answer == '':
#         answer = minute_to_string(current_shuttle)
#     else: # if there's more people than capacity of shuttles
#         answer = minute_to_string(answer)
#     return answer
